# %%
from numpy import random
import numpy

randomarray=random.randint(50, size=(25))

print("random array:",randomarray)
# Out:
# random array: [23 34 48 38  1 37 44  5 12 36 23 29 15 42 28 46 33 14 30  3 14 23  0 38
#  41]

# %%
unique_array =numpy.unique(randomarray)
print("unique array is ", unique_array)
# Out:
# unique array is  [ 0  1  3  5 12 14 15 23 28 29 30 33 34 36 37 38 41 42 44 46 48]

# %%
randomint = numpy.random.randint(0,150,10)
    
for i in unique_array:
    for j in randomint:
        if(i==j):
            test_dict[i] =1

for x,y in test_dict.items():
    print("The "+str(i)+" key value pair of dictionary is: ",x, y)
    i =i+1
# Out:
# The 48 key value pair of dictionary is:  1 1
# The 49 key value pair of dictionary is:  2 1
# The 50 key value pair of dictionary is:  7 colors
# The 51 key value pair of dictionary is:  8 colors
# The 52 key value pair of dictionary is:  16 colors
# The 53 key value pair of dictionary is:  17 1
# The 54 key value pair of dictionary is:  19 1
# The 55 key value pair of dictionary is:  22 colors
# The 56 key value pair of dictionary is:  26 colors
# The 57 key value pair of dictionary is:  28 colors
# The 58 key value pair of dictionary is:  30 colors
# The 59 key value pair of dictionary is:  32 colors
# The 60 key value pair of dictionary is:  34 colors
# The 61 key value pair of dictionary is:  39 1
# The 62 key value pair of dictionary is:  40 colors
# The 63 key value pair of dictionary is:  41 1
# The 64 key value pair of dictionary is:  48 colors
# The 65 key value pair of dictionary is:  14 1

# %%
# 2nd question
import random
import numpy
randomint = numpy.random.randint(0,150,10)

# %%
import pandas as pd
df = pd.read_csv('/Users/amulyageereddy/iris.csv')
for i in randomint:
    print("width for {} rows:{} ".format(i,df['sepal_width'][i]))
    print("length for {} rows:{} ".format(i,df['sepal_length'][i]))
# Out:
# width for 90 rows:2.6
# length for 90 rows:5.5
# width for 146 rows:2.5
# length for 146 rows:6.3
# width for 118 rows:2.6
# length for 118 rows:7.7
# width for 132 rows:2.8
# length for 132 rows:6.4
# width for 115 rows:3.2
# length for 115 rows:6.4
# width for 61 rows:3.0
# length for 61 rows:5.9
# width for 4 rows:3.6
# length for 4 rows:5.0
# width for 49 rows:3.3
# length for 49 rows:5.0
# width for 116 rows:3.0
# length for 116 rows:6.5
# width for 142 rows:2.7
# length for 142 rows:5.8

# %%
fig = df.hist(figsize = (20,8))

#from the below plots we can say that the sepal_width is normally distributed and petal_length is normally distibuted 
#and from petal_width and petal_length we can observe that they are left skewed and sepal_lenth is not normalized.

# %%
#3a  
housing = pd.read_csv("housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.plot.scatter( y = 'median_house_value' , x = 'housing_median_age')
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='median_house_value'>

# %%
# From the plot we can see that for each age we have houses ranging from 100k to 500k.
#There is no proper correlation between the median age and median value.
#So from the plot and the correlation we cant say that we can calculate the value of the house soley based on the median age
